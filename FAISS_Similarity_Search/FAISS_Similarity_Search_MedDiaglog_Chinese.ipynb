# %%
pip install faiss
# Out:
# Collecting faiss
#   Downloading faiss-1.5.3-cp37-cp37m-manylinux1_x86_64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 4.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from faiss) (1.19.5)
# Installing collected packages: faiss
# Successfully installed faiss-1.5.3

# %%
# !apt install libomp-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libomp5
# Suggested packages:
#   libomp-doc
# The following NEW packages will be installed:
#   libomp-dev libomp5
# 0 upgraded, 2 newly installed, 0 to remove and 37 not upgraded.
# Need to get 239 kB of archives.
# After this operation, 804 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libomp5 amd64 5.0.1-1 [234 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libomp-dev amd64 5.0.1-1 [5,088 B]
# Fetched 239 kB in 2s (125 kB/s)
# Selecting previously unselected package libomp5:amd64.
# (Reading database ... 155219 files and directories currently installed.)
# Preparing to unpack .../libomp5_5.0.1-1_amd64.deb ...
# Unpacking libomp5:amd64 (5.0.1-1) ...
# Selecting previously unselected package libomp-dev.
# Preparing to unpack .../libomp-dev_5.0.1-1_amd64.deb ...
# Unpacking libomp-dev (5.0.1-1) ...
# Setting up libomp5:amd64 (5.0.1-1) ...
# Setting up libomp-dev (5.0.1-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
# !pip3 install pickle5
import pickle5 as pickle
# Out:
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.11)

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# DATA_PATH = "gdrive/MyDrive"

# with open(DATA_PATH +'/mbert_chi_embeddings_229730.pkl','rb') as f:
#   embeddings = pickle.load(f)

# %%
DATA_PATH = "gdrive/MyDrive"

with open(DATA_PATH +'/bert_translated_229730.pkl','rb') as f:
  embeddings = pickle.load(f)

# %%
print(len(embeddings["chi_ques"]))
print(len(embeddings["chi_ans"]))
print(len(embeddings["translated_ques"]))
print(len(embeddings["translated_ans"]))
print(len(embeddings["ques_embeddings"]))
print(len(embeddings["ans_embeddings"]))
# Out:
# 229730
# 229730
# 229730
# 229730
# 229730
# 229730

# %%
import numpy as np 
import faiss

# %%
question_embedding = np.array(embeddings["ques_embeddings"])
answer_embedding = np.array(embeddings["ans_embeddings"])
print(question_embedding.shape)
print(answer_embedding.shape)
# Out:
# (229730, 768)
# (229730, 768)

# %%
dimension = 768
nlist = 5          # number of clusters
quantiser = faiss.IndexFlatL2(dimension)  
index_question = faiss.IndexIVFFlat(quantiser, dimension, nlist, faiss.METRIC_L2)
index_answer = faiss.IndexIVFFlat(quantiser, dimension, nlist, faiss.METRIC_L2)

# %%
print(index_question.is_trained)   # False
index_question.train(question_embedding)  # train on the database vectors
print(index_question.ntotal)   # 0
index_question.add(question_embedding)   # add the vectors and update the index
print(index_question.is_trained)  # True
print(index_question.ntotal)
# Out:
# False
# 0
# True
# 229730

# %%
print(index_answer.is_trained)   # False
index_answer.train(answer_embedding)  # train on the database vectors
print(index_answer.ntotal)   # 0
index_answer.add(answer_embedding)   # add the vectors and update the index
print(index_answer.is_trained)  # True
print(index_answer.ntotal)   # 29752
# Out:
# False
# 0
# True
# 229730

# %%
embedding_by_len = embeddings["chi_ques"].copy()
embedding_by_len.sort(key=len, reverse=True)

n = 15000

index = []

for i in range(n):
  index.append(embeddings["chi_ques"].index(embedding_by_len[i]))

# %%
len(index)
# Out:
# 15000

# %%
k = 4

result = []

for i in range(n):
  num = index[i]
  question_query_vector = np.array([embeddings["ques_embeddings"][num]])
  question_distances, question_indices = index_question.search(question_query_vector, k)
  
  answer_query_vector = np.array([embeddings["ans_embeddings"][num]])
  answer_distances, answer_indices = index_answer.search(answer_query_vector, k)
  
  for j in range(k):
    q_index = question_indices[0][j]
    if (q_index != num) and q_index in answer_indices[0]:
      if embeddings["chi_ques"][num] != embeddings["chi_ques"][q_index] and embeddings["chi_ans"][num] != embeddings["chi_ans"][q_index]:
        result.append((num, q_index))

# %%
print(result)
# Out:
# [(132470, 50565), (115836, 77898), (46155, 123791), (134981, 146055), (115845, 115848), (115845, 220466), (165429, 223460), (102572, 71278), (102572, 102407), (102572, 53863), (173193, 119473), (173193, 4241), (135388, 92902), (133460, 224725), (14147, 103276), (109853, 46518), (78793, 215973), (78793, 151971), (100188, 1782), (100188, 10083), (100308, 182116), (117307, 30085), (117307, 115435), (67761, 228388), (67761, 22901), (87533, 48607), (92778, 227250), (92778, 205373), (2853, 62102), (2853, 207905), (30897, 53159), (146055, 134981), (218046, 139757), (108066, 85706), (108066, 52768), (75274, 127204), (75274, 93423), (127204, 75274), (127204, 93423), (169074, 192494), (169074, 216951), (54871, 21136), (54871, 228120), (134553, 96106), (121782, 33292), (120603, 76448), (120603, 220366), (101257, 92785), (102520, 185083), (111501, 173472), (111501, 26243), (157408, 116922), (131007, 1920), (131007, 47700), (220140, 226769), (220140, 28243), (187481, 227215), (50398, 132868), (188817, 201982), (185860, 185866), (1788, 119327), (62191, 88764), (62191, 173362), (204218, 66671), (204218, 187710), (116787, 196671), (114164, 198662), (114164, 223357), (214504, 213933), (30434, 50275), (86734, 219339), (103225, 202479), (148091, 199591), (90131, 31732), (176541, 41394), (35353, 44999), (35353, 190966), (37442, 117187), (194720, 207905), (88471, 138613), (88471, 39135), (88471, 131305), (140085, 186385), (62921, 144836), (145308, 191014), (200460, 216395), (138555, 56566), (22138, 200959), (157567, 160703), (6558, 7448), (6558, 170489), (76448, 120603), (76448, 220366), (76456, 215979), (68748, 196828), (199823, 192795), (217683, 129839), (134649, 134644), (134649, 134648), (205705, 164152), (173497, 55446), (92326, 97329), (192269, 49869), (192269, 78436), (192269, 43923), (103172, 90276), (218547, 220719), (218547, 228427), (134651, 118212), (54326, 180603), (54326, 32389), (48523, 86483), (48523, 157654), (141277, 195498), (208190, 57553), (77346, 3530), (92135, 159006), (138606, 455), (138606, 120624), (86738, 161463), (71459, 80971), (62946, 77781), (61452, 221031), (200748, 201408), (152256, 220366), (750, 105761), (174368, 216764), (36405, 217258), (141233, 144636), (202553, 215976), (208346, 196742), (200701, 219520), (200701, 194634), (102309, 176814), (43288, 11332), (39135, 88471), (39135, 138613), (39135, 131305), (115304, 41186), (66313, 109086), (193885, 68395), (7448, 6558), (7448, 170489), (146325, 58189), (168597, 200680), (30606, 174683), (52077, 97768), (77142, 69401), (36519, 47236), (21624, 88963), (85057, 80971), (85057, 71459), (94510, 108271), (100184, 7501), (185062, 51133), (229516, 109459), (229516, 215475), (64631, 55918), (96089, 50857), (125581, 65971), (125581, 80693), (44696, 116921), (142653, 218942), (54990, 96423), (211856, 223336), (180782, 200758), (197788, 191314), (192411, 68734), (38708, 126731), (47688, 207629), (53159, 30897), (218592, 71038), (136550, 197280), (98445, 199221), (98445, 35983), (133978, 226957), (8101, 229090), (200994, 202552), (141602, 216764), (141602, 182120), (42642, 73936), (42642, 5046), (60982, 78224), (77470, 101311), (77470, 48253), (20926, 142209), (22482, 38246), (22482, 142653), (228785, 193967), (228785, 174695), (206720, 164361), (26432, 26431), (129993, 196244), (194415, 166169), (8424, 157913), (133543, 172673), (189921, 202435), (115440, 222573), (115440, 226229), (226590, 65025), (26168, 198701), (26168, 197116), (96828, 34242), (96828, 14444), (100986, 4547), (152657, 210139), (152657, 227837), (116134, 93229), (116134, 159332), (18655, 105864), (73193, 108284), (126554, 85653), (213469, 226460), (44999, 41171), (44999, 20955), (158280, 70198), (175471, 178951), (217757, 194486), (89786, 31896), (89786, 179130), (176564, 221715), (42516, 73753), (204493, 136496), (204493, 86919), (198868, 229416), (41290, 1617), (200768, 217452), (28217, 96348), (28217, 79873), (25223, 86261), (25223, 60972), (86766, 122354), (86766, 226878), (197588, 202890), (197588,  ...

# %%
print(len(result))
# Out:
# 9536

# %%
print(embeddings["translated_ques"][132470])
print(embeddings["translated_ans"][132470])
# Out:
# Fear of HIV/AIDS.Good evening, chief! Disturbing your marriage! I'm in pain! There are too many symptoms! 18 years of massage, bathing, massage, sucking my nipples, leaving a lot of saliva (not knowing if there's blood in the saliva), and I touched it a few times, and my hand's blistering position (the kind that can squeeze a little bit of blood, about 3 mm size) was under the no-name finger, and now I think it's the woman mechanic who threw up a lot of water (not knowing if there's blood in the saliva) on my nipples, and then I touched it a few times.After that, and after that, I discovered that the massage girl's neck was ringing and my neck was ringing for some time, and I was afraid that she was contagious in the window. Five days after the massage, I had a little pain in the back of my ear, and then two weeks later, I had a nausea and vomiting feeling (which lasted 10 days or so), three weeks with low blood lymphocytes, about three weeks of low lymph lymph lymph lymph lymph lymph lymphomy, three weeks of lymphomy lymphomy lymphomy, and then a lot of colored lymph swoll under the groin, lymphore under the lymphore, lymphore under the lymphore, lymphore in the chest, and lymphomy in the eye, especially in the following months and now, with two cramps on both sides of the bladder, and two cramps on the right side of the face, and the upper ear.Then, in more than a month, there was an irritation on the right and left arm, and in four months or so, the whole body was swollen, especially when the arm was sometimes brittle, the voice was a bit loud, the joints were sore for two months or so, especially when the hands were sore now, the hand and waist were subjected to a nuclear magnetic resonance examination, and it was found that soft tissue was swollen, the left face was numb in the ninth month, the eyes were strewn, the left nose and teeth were numb, there were so many months of farts and a little diarrhea, and then there were so many white things with hairlines on the tongue, there was a little whiteness in the lips, there was also a lot of blood in my lips, and it was so hot that I could eat it, it was so suffocate, there were too many symptoms, there were over 30 antigens in 13 months, and five nucles, and there were severe ins, and there were no sleep, and there were no sleeping pills, and there were a lot of nitible, and a little bit higher, and a little bit of anamine.Is it true that I've been married for so many symptoms, that I've been dying for so many years, that I don't have any other problems, that I'm afraid that I'm going to have to do it? One, please, please give me an analysis of my condition. Is it possible to have an infection? Is it possible? Two, three, three, 30 antigen antibodies and five nucleic acid penises, even if there's so many symptoms, that there's no chance that there's a long window period in the left eye? Three, I'm going to do it. Four, I'm not going to do it, I'm going to do it, I'm not going to have a nervous system, I'm not going to have a nervous system, I'm going to have a nervous system, I'm going to have a nervous system.The hand is thinning by 13.And look at your tongue when you've got the hang of your hand.Hello Director! I've been suffering from too many symptoms every day. Please give me another analysis of my condition. Since the massage, there have been symptoms, massage girls sucking on my nipples, and my hand's blistering position (the wound is a little deep, it's about 3 mm large) is under the no-name finger, and now it's the woman mechanic who threw up a lot of water (not knowing if there's blood in the saliva), on my nipples, and then I touch it with my hands.After that, and after that, I found that the girl's neck was swollen for a period of time, and I was afraid she had a little pain in the back of the ear five days after the massage. I had a little pain in the back of the ear for five days, and then two weeks of nausea (which lasted about 10 days), three weeks of low blo ...
# Negative, excluded.

# %%
print(embeddings["translated_ques"][50565])
print(embeddings["translated_ans"][50565])
# Out:
# Good morning, Director Zhang! Thank you!My mom and dad did the whole pulmonary test. I'll see you later.Chief Zhang, what do you need to do with the lung pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary pulmonary tests?
#  The pulmonary knot is a very high-density micropulmonary knot, which is too small to perform further tests for CT-guided pulmonary punctures and is more likely to take into account benignness.A review of the CT comparison will be available in three to six months.

# %%
for i in range(len(result)):
  first_index = result[i][0]
  second_index = result[i][1]

  first_q = embeddings["chi_ques"][first_index]
  first_a = embeddings["chi_ans"][second_index]
  first_t_q = embeddings["translated_ques"][first_index]
  first_t_a =embeddings["translated_ans"][second_index]
  first_q_embeddings = embeddings["ques_embeddings"][first_index]
  first_a_embeddings = embeddings["ans_embeddings"][second_index]

  second_q = embeddings["chi_ques"][second_index]
  second_a = embeddings["chi_ans"][first_index]
  second_t_q = embeddings["translated_ques"][second_index]
  second_t_a =embeddings["translated_ans"][first_index]
  second_q_embeddings = embeddings["ques_embeddings"][second_index]
  second_a_embeddings = embeddings["ans_embeddings"][first_index]

  embeddings["chi_ques"].append(first_q)
  embeddings["chi_ans"].append(first_a)
  embeddings["translated_ques"].append(first_t_q)
  embeddings["translated_ans"].append(first_t_a)
  embeddings["ques_embeddings"].append(first_q_embeddings)
  embeddings["ans_embeddings"].append(first_a_embeddings)

  embeddings["chi_ques"].append(second_q)
  embeddings["chi_ans"].append(second_a)
  embeddings["translated_ques"].append(second_t_q)
  embeddings["translated_ans"].append(second_t_a)
  embeddings["ques_embeddings"].append(second_q_embeddings)
  embeddings["ans_embeddings"].append(second_a_embeddings)

# %%
print(len(embeddings["chi_ques"]))
print(len(embeddings["chi_ans"]))
print(len(embeddings["translated_ques"]))
print(len(embeddings["translated_ans"]))
print(len(embeddings["ques_embeddings"]))
print(len(embeddings["ans_embeddings"]))
# Out:
# 248802
# 248802
# 248802
# 248802
# 248802
# 248802

# %%
pickle_out = open(DATA_PATH + "/ MedDialog_Translated_BERT.pkl", "wb")
pickle.dump(embeddings, pickle_out, pickle.HIGHEST_PROTOCOL)
pickle_out.close()
